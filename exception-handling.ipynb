# %%
#Exception handling
# terminates the program in between

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))
print(x/y)
print("hello students.....")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 x = int(input("Enter x: "))
#       2 y = int(input("Enter y: "))
# ----> 3 print(x/y)
#       4 print("hello students.....")
#
# ZeroDivisionError: division by zero

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))
try:
    ans = x/y
    print(div)
except ZeroDivisionError as e: # you can try with y as value 0 to get the error
    print("Error: ", e) 
except NameError as e:
    print("Error: ", e)
print("hello students.....the remaining lines")
# Out:
# Error:  name 'div' is not defined
# hello students.....the remaining lines

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))
try:
    ans = x/y
    print(div)  # 
except(ZeroDivisionError,NameError)as e: # you can try with y as value 0 to get the error
    print("Error: ", e) 
print("hello students.....the remaining lines")
# Out:
# Error:  name 'div' is not defined
# hello students.....the remaining lines

# %%
x = 10
y = 2
try:
    ans = x/y
    print("ans is", div)
except Exception as e:
    print("exception handled: ", e)
else:
    print("else block executed") # only executes when there is no exception
finally:
    print("finally block executed") # executes in all cases whether there is an exception or not
# Out:
# exception handled:  name 'div' is not defined

# %%
# raise

age = int(input("Enter your age: "))
try:
    if age < 18:
        raise ValueError("here a message is: invalid age") # you can raise your own exception with the help of raise keyword
except ValueError as e:
        print(e)
print("hello students....")
# Out:
# here a message is: invalid age
# hello students....

# %%
# custom exception class
class PercentGreaterThan100(Exception):
    '''this is an exception class'''
    pass

per = float(input("Enter per:  "))
try:
    if per > 100:
        raise PercentGreaterThan100("percentage cannot be greater than 100")
except PercentGreaterThan100 as e:
        print(e)
# Out:
# percentage cannot be greater than 100

# %%
class
