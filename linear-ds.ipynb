# %% [markdown]
# ### Linked List
# - has nodes, nodes have data and a pointer to the next node.

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        

class LinkedList:
    def __init__(self):
         self.start = None
        
    def createNode(self): # creating a new node by taking input from the user
        data = int(input("Enter data: "))
        return Node(data)

    def insertAtFirst(self): #inserting a node at the beginning of the linked list
        if self.start is None: # checking if the linked list is empty
            self.start = self.createNode()
        else:
            newNode = self.createNode()
            newNode.next = self.start
            self.start = newNode

    def insertAtLast(self): # insert at end of the linked list
        if self.start is None:
            self.start = self.createNode()
        else:
            temp = self.start
            while temp.next != None:
                temp = temp.next

            temp.next = self.createNode()
            temp.next.next = None
            
    def display(self): # displaying the linked list
        temp = self.start
        if temp == None:
            print("linked list is empty")
        while temp != None:
            print(temp.data,end = '->')
            temp = temp.next
        print('None')

    def deleteAtFirst(self):
        if self.start is None:
            print("linked list is empty")
        else:
            temp = self.start
            self.start = self.start.next
            temp.next = None
            temp = None
    
    def deleteAtLast(self):
        if self.start is None:
            print("Linked list is empty")
        elif self.start.next is None:
            self.start = None
        else:
            temp = self.start
            while(temp.next.next != None):
                temp = temp.next
            temp.next = None
            temp = None

    def search(self, key):
        if self.start is None:
            print("LL is empty")
        else:
            temp = self.start
            c = 0
            while temp is not None:
                if(temp.data == key):
                    print("found in LL",c)
                    break
                else:
                    c += 1
                    temp = temp.next

    def insertAtIndex(self, index):
        if index < 1:
            print("not valid")
        elif index == 1:
            self.insertAtFirst()
        elif index > 1:
            temp = self.start
            for i in range(index - 2):
                if temp is None or temp.next is None:
                    print("invalid index")
                    break
                temp = temp.next
        temp.                 






# print(start.data, end = '->')
# print(start.next.data,end = '->')
# print(start.next.next.data,end = '->')
# print(start.next.next.next.data,end = '->None')

l1 = LinkedList()
l1.insertAtFirst()
l1.insertAtFirst()
l1.insertAtFirst()
l1.display()
l1.insertAtLast()
l1.display()
l1.deleteAtFirst()
l1.display()
l1.deleteAtLast()
l1.display()
l1.search(10)
# Out:
#   Cell In[22], line 90
#     l1 = LinkedList()
#                      ^
# IndentationError: expected an indented block after 'if' statement on line 79
